# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import nltk
nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
import joblib
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.base import BaseEstimator,TransformerMixin
# %matplotlib inline
plt.rcParams["figure.figsize"] = (8,8)
plt.rcParams['font.size'] = 16
# Out:
# [nltk_data] Downloading package punkt to /home/aaron/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/aaron/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/aaron/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# load data from database
engine = create_engine('sqlite:///../data/DisasterResponse.db')
df = pd.read_sql_table('disaster_data', 'sqlite:///../data/DisasterResponse.db')  
X = df["message"]
y = df.drop(["message", "id", "original", "genre"], axis=1)

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

def tokenize(text):
    # Unify URLs with a placeholder
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, "urlplaceholder")
        
    # Split text into words
    tokens = nltk.word_tokenize(text)
    
    # Group inflected words, remove whitespace, transform all to lowercase
    lemmatizer = WordNetLemmatizer()
    clean_tokens = [lemmatizer.lemmatize(x).lower().strip() for x in tokens]
    
    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
classifier = RandomForestClassifier()

pipeline = Pipeline([
    ('features', FeatureUnion([
        ('text_pipeline', Pipeline([
            ('vect', CountVectorizer(tokenizer=tokenize)),
            ('tfidf', TfidfTransformer())
        ])),
    ])),

    ('clf', MultiOutputClassifier(classifier))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y);
model = pipeline;
model.fit(X_train, y_train);

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_pred = model.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns = y.columns)

# %%
accuracy = []
for col in y.columns:
    print(f"Category: {col}")
    report = classification_report(y_test[col],y_pred[col], output_dict=False)
    print(report)
    accuracy.append(classification_report(y_test[col],y_pred[col], output_dict=True)["accuracy"])
# Out:
# Category: related
#               precision    recall  f1-score   support
#
#        False       0.74      0.28      0.41      1587
#         True       0.81      0.97      0.88      4967
#
#     accuracy                           0.80      6554
#    macro avg       0.77      0.62      0.64      6554
# weighted avg       0.79      0.80      0.77      6554
#
# Category: request
#               precision    recall  f1-score   support
#
#        False       0.90      0.99      0.94      5457
#         True       0.87      0.43      0.58      1097
#
#     accuracy                           0.89      6554
#    macro avg       0.88      0.71      0.76      6554
# weighted avg       0.89      0.89      0.88      6554
#
# Category: offer
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      6524
#         True       0.00      0.00      0.00        30
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Category: aid_related
#               precision    recall  f1-score   support
#
#        False       0.77      0.87      0.82      3889
#         True       0.77      0.62      0.68      2665
#
#     accuracy                           0.77      6554
#    macro avg       0.77      0.75      0.75      6554
# weighted avg       0.77      0.77      0.76      6554
#
# Category: medical_help
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96      5997
#         True       0.72      0.05      0.09       557
#
#     accuracy                           0.92      6554
#    macro avg       0.82      0.52      0.52      6554
# weighted avg       0.90      0.92      0.88      6554
#
# Category: medical_products
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6211
#         True       0.69      0.05      0.10       343
#
#     accuracy                           0.95      6554
#    macro avg       0.82      0.53      0.54      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Category: search_and_rescue
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.99      6364
#         True       0.57      0.04      0.08       190
#
#     accuracy                           0.97      6554
#    macro avg       0.77      0.52      0.53      6554
# weighted avg       0.96      0.97      0.96      6554
#
# Category: security
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6452
#         True       0.00      0.00      0.00       102
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.98      0.98      6554
#
# Category: military
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98      6350
#         True       0.75      0.01      0.03       204
#
#     accuracy                           0.97      6554
#    macro avg       0.86      0.51      0.51      6554
# weighted avg       0.96      0.97      0.95      6554
#
# Category: child_alone
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# Category: water
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6122
#         True       0.89      0.28      0.43       432
#
#     accuracy                           0.95      6554
#    macro avg       0.92      0.64      0.70      6554
# weighted avg       0.95      0.95      0.94      6554
#
# Category: food
#               precision    recall  f1-score   support
#
#        False       0.94      0.99      0.96      5814
#         True       0.86      0.47      0.61       740
#
#     accuracy                           0.93      6554
#    macro avg       0.90      0.73      0.78      6554
# weighted avg       0.93      0.93      0.92      6554
#
# Category: shelter
#               precision    recall  f1-score   support
#
#        False       0.93      1.00      0.96      5996
#         True       0.89      0.19      0.31       558
#
#     accuracy                           0.93      6554
#    macro avg       0.91      0.59      0.64      6554
# weighted avg       0.93      0.93      0.91      6554
#
# Category: clothing
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      6452
#         True       0.67      0.04      0.07       102
#
#     accuracy                           0.98      6554
#    macro avg       0.83      0.52      0.53      6554
# weighted avg       0.98      0.98      0.98      6554
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Category: money
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6391
#         True       1.00      0.01      0.02       163
#
#     accuracy                           0.98      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.98      0.98      0.96      6554
#
# Category: missing_people
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      6481
#         True       1.00      0.01      0.03        73
#
#     accuracy                           0.99      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.99      0.99      0.98      6554
#
# Category: refugees
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6314
#         True       1.00      0.02      0.03       240
#
#     accuracy                           0.96      6554
#    macro avg       0.98      0.51      0.51      6554
# weighted avg       0.97      0.96      0.95      6554
#
# Category: death
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6259
#         True       0.83      0.15      0.25       295
#
#     accuracy                           0.96      6554
#    macro avg       0.89      0.57      0.61      6554
# weighted avg       0.96      0.96      0.95      6554
#
# Category: other_aid
#               precision    recall  f1-score   support
#
#        False       0.87      1.00      0.93      5704
#         True       0.67      0.01      0.03       850
#
#     accuracy                           0.87      6554
#    macro avg       0.77      0.51      0.48      6554
# weighted avg       0.85      0.87      0.81      6554
#
# Category: infrastructure_related
#               precision    recall  f1-score   support
#
#        False       0.94      1.00      0.97      6144
#         True       0.00      0.00      0.00       410
#
#     accuracy                           0.94      6554
#    macro avg       0.47      0.50      0.48      6554
# weighted avg       0.88      0.94      0.91      6554
#
# Category: transport
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6269
#         True       0.83      0.07      0.13       285
#
#     accuracy                           0.96      6554
#    macro avg       0.90      0.53      0.55      6554
# weighted avg       0.95      0.96      0.94      6554
#
# Category: buildings
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.98      6243
#         True       0.78      0.05      0.09       311
#
#     accuracy                           0.95      6554
#    macro avg       0.87      0.52      0.53      6554
# weighted avg       0.95      0.95      0.93      6554
#
# Category: electricity
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6444
#         True       1.00      0.01      0.02       110
#
#     accuracy                           0.98      6554
#    macro avg       0.99      0.50      0.50      6554
# weighted avg       0.98      0.98      0.98      6554
#
# Category: tools
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      6510
#         True       0.00      0.00      0.00        44
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# Category: hospitals
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      6485
#         True       0.00      0.00      0.00        69
#
#     accuracy                           0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Category: shops
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      6526
#         True       0.00      0.00      0.00        28
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Category: aid_centers
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      6486
#         True       0.00      0.00      0.00        68
#
#     accuracy                           0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Category: other_infrastructure
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6269
#         True       0.00      0.00      0.00       285
#
#     accuracy                           0.96      6554
#    macro avg       0.48      0.50      0.49      6554
# weighted avg       0.91      0.96      0.94      6554
#
# Category: weather_related
#               precision    recall  f1-score   support
#
#        False       0.87      0.97      0.92      4787
#         True       0.88      0.62      0.73      1767
#
#     accuracy                           0.88      6554
#    macro avg       0.88      0.80      0.82      6554
# weighted avg       0.88      0.88      0.87      6554
#
# Category: floods
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6036
#         True       0.92      0.36      0.52       518
#
#     accuracy                           0.95      6554
#    macro avg       0.94      0.68      0.75      6554
# weighted avg       0.95      0.95      0.94      6554
#
# Category: storm
#               precision    recall  f1-score   support
#
#        False       0.94      0.99      0.97      5967
#         True       0.81      0.38      0.52       587
#
#     accuracy                           0.94      6554
#    macro avg       0.87      0.69      0.74      6554
# weighted avg       0.93      0.94      0.93      6554
#
# Category: fire
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      6490
#         True       0.00      0.00      0.00        64
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.98      0.99      0.99      6554
#
# Category: earthquake
#               precision    recall  f1-score   support
#
#        False       0.98      0.99      0.98      5970
#         True       0.91      0.75      0.82       584
#
#     accuracy                           0.97      6554
#    macro avg       0.94      0.87      0.90      6554
# weighted avg       0.97      0.97      0.97      6554
#
# Category: cold
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6426
#         True       1.00      0.05      0.10       128
#
#     accuracy                           0.98      6554
#    macro avg       0.99      0.53      0.55      6554
# weighted avg       0.98      0.98      0.97      6554
#
# Category: other_weather
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6214
#         True       0.50      0.02      0.04       340
#
#     accuracy                           0.95      6554
#    macro avg       0.72      0.51      0.51      6554
# weighted avg       0.93      0.95      0.92      6554
#
# Category: direct_report
#               precision    recall  f1-score   support
#
#        False       0.87      0.99      0.92      5325
#         True       0.86      0.36      0.51      1229
#
#     accuracy                           0.87      6554
#    macro avg       0.86      0.67      0.72      6554
# weighted avg       0.87      0.87      0.85      6554
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
accuracy_df = pd.DataFrame(accuracy, list(y.columns), columns=["base"]);
accuracy_df.plot(kind="bar", legend=False, xlabel="Categories", ylabel="accuracy");

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {
    'features__text_pipeline__vect__ngram_range': ((1, 1), (1, 2)),
    'features__text_pipeline__vect__max_df': (0.5, 0.75, 1.0),
    'features__text_pipeline__vect__max_features': (None, 5000, 10000),
    'features__text_pipeline__tfidf__use_idf': (True, False),
    'clf__estimator__n_estimators': [50, 100, 200],
    'clf__estimator__min_samples_split': [2, 3, 4],
    'features__transformer_weights': (
        {'text_pipeline': 1, 'starting_verb': 0.5},
        {'text_pipeline': 0.5, 'starting_verb': 1},
        {'text_pipeline': 0.8, 'starting_verb': 1},
    )    
}

cv = GridSearchCV(pipeline, param_grid=parameters)

cv.fit(X_train, y_train)
y_pred = cv.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns = y.columns)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
grid_search_accuracy
for col in y.columns:
    print(f"Category: {col}")
    report = classification_report(y_test[col],y_pred[col], output_dict=False)
    print(report)

# %%
print(cv.best_params_)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
class StartingVerbExtractor(BaseEstimator, TransformerMixin):

    def starting_verb(self, text):
        sentence_list = nltk.sent_tokenize(text)
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            first_word, first_tag = pos_tags[0]
            if first_tag in ['VB', 'VBP'] or first_word == 'RT':
                return True
        return False

    def fit(self, x, y=None):
        return self

    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)

# %%
classifier = RandomForestClassifier()

pipeline = Pipeline([
    ('features', FeatureUnion([
        ('text_pipeline', Pipeline([
            ('vect', CountVectorizer(tokenizer=tokenize)),
            ('tfidf', TfidfTransformer())
        ])),
        
        ('starting_verb', StartingVerbExtractor())
    ])),

    ('clf', MultiOutputClassifier(classifier))
])

# %%
model = pipeline;
model.fit(X_train, y_train);

# %%
y_pred = model.predict(X_test)
y_pred = pd.DataFrame(y_pred, columns = y.columns)

# %%
add_feature_accuracy = []
for col in y.columns:
    print(f"Category: {col}")
    report = classification_report(y_test[col],y_pred[col], output_dict=False)
    print(report)
    add_feature_accuracy.append(classification_report(y_test[col],y_pred[col], output_dict=True)["accuracy"])
# Out:
# Category: related
#               precision    recall  f1-score   support
#
#        False       0.74      0.30      0.43      1587
#         True       0.81      0.97      0.88      4967
#
#     accuracy                           0.81      6554
#    macro avg       0.78      0.63      0.65      6554
# weighted avg       0.79      0.81      0.77      6554
#
# Category: request
#               precision    recall  f1-score   support
#
#        False       0.89      0.99      0.94      5457
#         True       0.88      0.41      0.56      1097
#
#     accuracy                           0.89      6554
#    macro avg       0.89      0.70      0.75      6554
# weighted avg       0.89      0.89      0.88      6554
#
# Category: offer
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      6524
#         True       0.00      0.00      0.00        30
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Category: aid_related
#               precision    recall  f1-score   support
#
#        False       0.77      0.88      0.82      3889
#         True       0.78      0.61      0.68      2665
#
#     accuracy                           0.77      6554
#    macro avg       0.77      0.74      0.75      6554
# weighted avg       0.77      0.77      0.76      6554
#
# Category: medical_help
#               precision    recall  f1-score   support
#
#        False       0.92      1.00      0.96      5997
#         True       0.60      0.04      0.08       557
#
#     accuracy                           0.92      6554
#    macro avg       0.76      0.52      0.52      6554
# weighted avg       0.89      0.92      0.88      6554
#
# Category: medical_products
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6211
#         True       0.76      0.05      0.09       343
#
#     accuracy                           0.95      6554
#    macro avg       0.86      0.52      0.53      6554
# weighted avg       0.94      0.95      0.93      6554
#
# Category: search_and_rescue
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.99      6364
#         True       0.65      0.07      0.12       190
#
#     accuracy                           0.97      6554
#    macro avg       0.81      0.53      0.55      6554
# weighted avg       0.96      0.97      0.96      6554
#
# Category: security
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6452
#         True       0.00      0.00      0.00       102
#
#     accuracy                           0.98      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.97      0.98      0.98      6554
#
# Category: military
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98      6350
#         True       0.75      0.01      0.03       204
#
#     accuracy                           0.97      6554
#    macro avg       0.86      0.51      0.51      6554
# weighted avg       0.96      0.97      0.95      6554
#
# Category: child_alone
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      6554
#
#     accuracy                           1.00      6554
#    macro avg       1.00      1.00      1.00      6554
# weighted avg       1.00      1.00      1.00      6554
#
# Category: water
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6122
#         True       0.91      0.22      0.35       432
#
#     accuracy                           0.95      6554
#    macro avg       0.93      0.61      0.66      6554
# weighted avg       0.95      0.95      0.93      6554
#
# Category: food
#               precision    recall  f1-score   support
#
#        False       0.93      0.99      0.96      5814
#         True       0.87      0.46      0.60       740
#
#     accuracy                           0.93      6554
#    macro avg       0.90      0.72      0.78      6554
# weighted avg       0.93      0.93      0.92      6554
#
# Category: shelter
#               precision    recall  f1-score   support
#
#        False       0.93      1.00      0.96      5996
#         True       0.88      0.23      0.37       558
#
#     accuracy                           0.93      6554
#    macro avg       0.91      0.61      0.66      6554
# weighted avg       0.93      0.93      0.91      6554
#
# Category: clothing
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6452
#         True       0.50      0.03      0.06       102
#
#     accuracy                           0.98      6554
#    macro avg       0.74      0.51      0.52      6554
# weighted avg       0.98      0.98      0.98      6554
#
# Category: money
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6391
#         True       1.00      0.01      0.02       163
#
#     accuracy                           0.98      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.98      0.98      0.96      6554
#
# Category: missing_people
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      6481
#         True       1.00      0.01      0.03        73
#
#     accuracy                           0.99      6554
#    macro avg       0.99      0.51      0.51      6554
# weighted avg       0.99      0.99      0.98      6554
#
# Category: refugees
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6314
#         True       0.56      0.02      0.04       240
#
#     accuracy                           0.96      6554
#    macro avg       0.76      0.51      0.51      6554
# weighted avg       0.95      0.96      0.95      6554
#
# Category: death
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6259
#         True       0.83      0.15      0.26       295
#
#     accuracy                           0.96      6554
#    macro avg       0.90      0.58      0.62      6554
# weighted avg       0.96      0.96      0.95      6554
#
# Category: other_aid
#               precision    recall  f1-score   support
#
#        False       0.87      1.00      0.93      5704
#         True       0.64      0.01      0.02       850
#
#     accuracy                           0.87      6554
#    macro avg       0.76      0.50      0.48      6554
# weighted avg       0.84      0.87      0.81      6554
#
# Category: infrastructure_related
#               precision    recall  f1-score   support
#
#        False       0.94      1.00      0.97      6144
#         True       0.00      0.00      0.00       410
#
#     accuracy                           0.94      6554
#    macro avg       0.47      0.50      0.48      6554
# weighted avg       0.88      0.94      0.91      6554
#
# Category: transport
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6269
#         True       0.73      0.08      0.15       285
#
#     accuracy                           0.96      6554
#    macro avg       0.84      0.54      0.56      6554
# weighted avg       0.95      0.96      0.94      6554
#
# Category: buildings
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6243
#         True       0.69      0.08      0.14       311
#
#     accuracy                           0.95      6554
#    macro avg       0.83      0.54      0.56      6554
# weighted avg       0.94      0.95      0.94      6554
#
# Category: electricity
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6444
#         True       0.50      0.01      0.02       110
#
#     accuracy                           0.98      6554
#    macro avg       0.74      0.50      0.50      6554
# weighted avg       0.98      0.98      0.98      6554
#
# Category: tools
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      6510
#         True       0.00      0.00      0.00        44
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      0.99      0.99      6554
#
# Category: hospitals
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      6485
#         True       0.00      0.00      0.00        69
#
#     accuracy                           0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Category: shops
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      6526
#         True       0.00      0.00      0.00        28
#
#     accuracy                           1.00      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.99      1.00      0.99      6554
#
# Category: aid_centers
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      0.99      6486
#         True       0.00      0.00      0.00        68
#
#     accuracy                           0.99      6554
#    macro avg       0.49      0.50      0.50      6554
# weighted avg       0.98      0.99      0.98      6554
#
# Category: other_infrastructure
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98      6269
#         True       0.00      0.00      0.00       285
#
#     accuracy                           0.96      6554
#    macro avg       0.48      0.50      0.49      6554
# weighted avg       0.91      0.96      0.94      6554
#
# Category: weather_related
#               precision    recall  f1-score   support
#
#        False       0.87      0.97      0.92      4787
#         True       0.88      0.61      0.72      1767
#
#     accuracy                           0.87      6554
#    macro avg       0.87      0.79      0.82      6554
# weighted avg       0.87      0.87      0.86      6554
#
# Category: floods
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6036
#         True       0.92      0.36      0.52       518
#
#     accuracy                           0.95      6554
#    macro avg       0.93      0.68      0.75      6554
# weighted avg       0.95      0.95      0.94      6554
#
# Category: storm
#               precision    recall  f1-score   support
#
#        False       0.94      0.99      0.97      5967
#         True       0.79      0.40      0.53       587
#
#     accuracy                           0.94      6554
#    macro avg       0.86      0.69      0.75      6554
# weighted avg       0.93      0.94      0.93      6554
#
# Category: fire
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      6490
#         True       0.00      0.00      0.00        64
#
#     accuracy                           0.99      6554
#    macro avg       0.50      0.50      0.50      6554
# weighted avg       0.98      0.99      0.99      6554
#
# Category: earthquake
#               precision    recall  f1-score   support
#
#        False       0.98      0.99      0.99      5970
#         True       0.91      0.77      0.83       584
#
#     accuracy                           0.97      6554
#    macro avg       0.94      0.88      0.91      6554
# weighted avg       0.97      0.97      0.97      6554
#
# Category: cold
#               precision    recall  f1-score   support
#
#        False       0.98      1.00      0.99      6426
#         True       0.92      0.09      0.16       128
#
#     accuracy                           0.98      6554
#    macro avg       0.95      0.54      0.57      6554
# weighted avg       0.98      0.98      0.97      6554
#
# Category: other_weather
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97      6214
#         True       0.59      0.03      0.06       340
#
#     accuracy                           0.95      6554
#    macro avg       0.77      0.51      0.51      6554
# weighted avg       0.93      0.95      0.93      6554
#
# Category: direct_report
#               precision    recall  f1-score   support
#
#        False       0.87      0.99      0.92      5325
#         True       0.87      0.35      0.50      1229
#
#     accuracy                           0.87      6554
#    macro avg       0.87      0.67      0.71      6554
# weighted avg       0.87      0.87      0.85      6554
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/aaron/anaconda3/envs/udacity/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
accuracy_df["add_feature"] = add_feature_accuracy

# %%
accuracy_df.plot(kind="bar", legend=False, xlabel="Categories", ylabel="accuracy");

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
joblib.dump(pipeline, "model.pkl")
# Out:
# ['model.pkl']

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
